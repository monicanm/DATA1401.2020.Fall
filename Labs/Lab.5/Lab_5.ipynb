# %% [markdown]
# # Lab 5- Object Oriented Programming
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github//afarbin/DATA1401-Spring-2020/blob/master/Labs/Lab-5/Lab-5.ipynb)
#
# For all of the exercises below, make sure you provide tests of your solutions.

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
class counter:
    def __init__(self,max_val):
        self.max_val=max_val
        self.cur_val=x       
    def increment(self,x):
        x = self.cur_val
        if self.cur_val<self.max_val:
            self.cur_val+=1
            return self.cur_val
        elif self.cur_val==self.max_val:
            self.cur_val+=1
            return self.cur_val
        elif self.cur_val==0:
            self.cur_val+=1
            return self.cur_val
        else:
            print("Max value reached.")           
    def reset(self):
        self.cur_val=1
        return self.cur_val

# %%
x=1
my_counter=counter(3)

# %%
print(my_counter.increment(1))
print(my_counter.increment(3))
print(my_counter.increment(20))
print(my_counter.increment(0))
print(my_counter.increment(66))
print(my_counter.reset())
# Out:
# 2
# 3
# 4
# Max value reached.
# None
# Max value reached.
# None
# 1

# %%
x=100
my_counter.cur_val=100
print(my_counter.increment(1))
print(my_counter.increment(3))
print(my_counter.increment(20))
print(my_counter.increment(0))
print(my_counter.increment(66))
print(my_counter.reset())
# Out:
# Max value reached.
# None
# Max value reached.
# None
# Max value reached.
# None
# Max value reached.
# None
# Max value reached.
# None
# 1

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
class counter:
    def __init__(self,max_val):
        self.__max_val=max_val
        self.__cur_val=x       
    def increment(self,x):
        x = self.cur_val
        if self.cur_val<self.max_val:
            self.cur_val+=1
            return self.cur_val
        elif self.cur_val==self.max_val:
            self.cur_val+=1
            return self.cur_val
        elif self.cur_val==0:
            self.cur_val+=1
            return self.cur_val
        else:
            print("Max value reached.")
    def reset(self):
        self.__cur_val=x
        return self.cur_val        
    def cur_val(self):
        return self.__cur_val
    def max_val(self):
        return self.__max_val
        max_val.close()

# %%
max_val = 50
my_counter=counter(max_val)

# %%
x=1
print(my_counter.cur_val())
print(max_val)
print(my_counter.max_val())
# Out:
# 100
# 50
# 50

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and parameter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class Canvas:
    def __init__(self, width, height):
        self.width = width
        self.height = height
        self.data = [[' '] * width for i in range(height)]

    def set_pixel(self, row, col, char='*'):
        self.data[row][col] = char

    def get_pixel(self, row, col):
        return self.data[row][col]
    
    def h_line(self, x, y, w, **kargs):
        for i in range(x,x+w):
            self.set_pixel(i,y, **kargs)

    def v_line(self, x, y, h, **kargs):
        for i in range(y,y+h):
            self.set_pixel(x,i, **kargs)
            
    def line(self, x1, y1, x2, y2, **kargs):
        slope = (y2-y1) / (x2-x1)
        for y in range(y1,y2):
            x= int(slope * y)
            self.set_pixel(x,y, **kargs)
            
    def display(self):
        print("\n".join(["".join(row) for row in self.data]))

# %%
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height
        self.data = [[' '] * width for i in range(height)]
    def display(self):
        print("\n".join(["".join(row) for row in self.data]))
    def __init__(self, width,height,x, y, **kwargs):
        Shape.__init__(self, **kwargs)
        self.width = width
        self.height = height
        self.x = x
        self.y = y
    def paint(self, canvas):
        canvas.h_line(self.width, self.height, self.x, **self.kwargs)
        canvas.h_line(self.width, self.height + self.y, self.x+1, **self.kwargs)
        canvas.v_line(self.width, self.height, self.y, **self.kwargs)
        canvas.v_line(self.width + self.x, self.height, self.y, **self.kwargs)
    def area(self,width,height):
        return (self.width*self.height)
    def perimeter(self,width,height):
        return 2*(self.width+self.height)
    def width(self):
        return self.width

# %%
c1=Canvas(50,40)
r1 = Rectangle(5,10,15,20,char="^")
out = r1.paint(c1)
print(r1.area(5,10))
print(r1.perimeter(5,10))
print(r1.x)
print(c1.display())
# Out:
# 50
# 30
# 15
#
#
#
#
#
#           ^^^^^^^^^^^^^^^^^^^^^
#           ^                   ^
#           ^                   ^
#           ^                   ^
#           ^                   ^
#           ^                   ^
#           ^                   ^
#           ^                   ^
#           ^                   ^
#           ^                   ^
#           ^                   ^
#           ^                   ^
#           ^                   ^
#           ^                   ^
#           ^                   ^
#           ^^^^^^^^^^^^^^^^^^^^^
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# None

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and parameter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class Circle:
    def __init__(self, color, radius):
        self.radius = radius
        self.color = color 
    def circle(self, r):
        self.radius = self.radius + r
        return (self.radius)
    def displayc(self):
        plt.gca().add_patch(plt.Circle((0, 0), radius=self.radius, fc=self.color))
        plt.axis('scaled')
        plt.show() 
        print('Radius of object:',C1.radius)

# %%
C1 = Circle('red',10)
C1.displayc()
# Out:
# Radius of object: 10

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as dummy functions. Re-implement those classes to inherit from the base class and overload the functions accordingly.

# %%
class Shape:
    def __init__(self, name="", **kwargs):
        self.name=name
        self.kwargs=kwargs    
    def paint(self, canvas): pass 
class Rectangle(Shape):
    def __init__(self, x, y, w, h, **kwargs):
        Shape.__init__(self, **kwargs)
        self.x = x
        self.y = y
        self.w = w
        self.h = h
    def paint(self, canvas):
        canvas.h_line(self.x, self.y, self.w, **self.kwargs)
        canvas.h_line(self.x, self.y + self.h, self.w+1, **self.kwargs)
        canvas.v_line(self.x, self.y, self.h, **self.kwargs)
        canvas.v_line(self.x + self.w, self.y, self.h, **self.kwargs) 
class Circle(Shape):
    def __init__(self, color, radius):
        self.radius = radius
        self.color = color 
    def circle(self, r):
        self.radius = self.radius + r
        return(self.radius)
    def displayc(self):
        plt.gca().add_patch(plt.Circle((0, 0), radius=self.radius, fc=self.color))
        plt.axis('scaled')
        plt.show()  
        print('Radius of object:',C1.radius)

# %% [markdown]
# 6. Implement an analogous triangle class.

# %%
class CompoundShape(Shape):
    def __init__(self, shapes):
        self.shapes = shapes

    def paint(self, canvas):
        for s in self.shapes:
            s.paint(canvas)

# %%
class Triangle(Shape):
    class Right_Sides:  
          def __init__(self, x, y, w,h, **kwargs):
              Shape.__init__(self, **kwargs)
              self.x = x
              self.y = y
              self.w = w
              self.h = h
              w = math.sqrt((x**2)+(y**2))
              x = math.sqrt((w**2)-(y**2))
              y = math.sqrt((w**2)-(x**2))
          def area(self,x,y):
              return (self.x*self.y)
          def perimeter(self,x,y):
              return 2*(self.x+self.y)
          def x(self):
              return self.x
          def paint(self, canvas):
              #canvas.v_line(self.x, (self.y), (self.w), **self.kwargs)  # top
              canvas.h_line(self.x, self.y, self.w, **self.kwargs) # left side
              #canvas.h_line(self.x, self.y + self.w, self.w, **self.kwargs) # right side
              canvas.v_line(self.x + self.w, self.y,self.h, **self.kwargs) # bottom
    class Line:
        def __init__(self, x, y, w,h, **kwargs):
            Shape.__init__(self, **kwargs)
            self.x = x
            self.y = y
            self.w = w
            self.h = h
        def paint(self, canvas): 
            canvas.line(self.x, self.y, self.w, self.h,**self.kwargs) # bottom

# %%
c3=Canvas(40,30)   
tR = (Triangle(Shape).Right_Sides(10,10,19,20,char='.'))
tL =(Triangle(Shape).Line(11,11,29,29,char='.'))
t2 = CompoundShape((Triangle((tR,tL))))
t2.paint(c3) 
c3.display()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-b40fe2a7ec41> in <module>()
#       3 tL =(Triangle(Shape).Line(11,11,29,29,char='.'))
#       4 t2 = CompoundShape((Triangle((tR,tL))))
# ----> 5 t2.paint(c3)
#       6 c3.display()
#
# <ipython-input-80-a686a036130c> in paint(self, canvas)
#       4
#       5     def paint(self, canvas):
# ----> 6         for s in self.shapes:
#       7             s.paint(canvas)
#
# TypeError: 'Triangle' object is not iterable

# %% [markdown]
# 7. Add a function to the object classes that test if a given set of $x$ and $y$ coordinates are inside of the object.

# %%
class Circle(Shape):
    def __init__(self,radius):
        self.radius = radius
    def circle(self, r):
        self.radius = self.radius + r
        return(self.radius)
    def displayc(self):
        plt.gca().add_patch(plt.Circle((0, 0), radius=self.radius))
        plt.axis('scaled')
        plt.show()  
        print('Radius of object:',C1.radius)
    def ordered():
        for radius in range(0,270,17):
            x = math.cos(radius)
            y = math.sin(radius) 
            print((x,y))
    def __lt__(self,other):
        return self.ordered < other.ordered
    def __gt__(self,other):
        return self.ordered > other.ordered

# %%
C1 = Circle.ordered()
C2 = Circle(50)   
print(C2 > C1)

# %% [markdown]
# 8. Add a function to the object classes that return a list of up to 16 pairs of  $x$ and $y$ points on the parameter of the object.

# %%
class Circle(Shape):
    def __init__(self,radius):
        self.radius = radius
    def circle(self, r):
        self.radius = self.radius + r
        return(self.radius)
    def displayc(self):
        plt.gca().add_patch(plt.Circle((0, 0), radius=self.radius))
        plt.axis('scaled')
        plt.show()  
        print('Radius of object:',C1.radius)
    def __lt__(self,other):
        return self.radius < other.radius
    def __gt__(self,other):
        return self.radius > other.radius
    def ordered():
        for radius in range(0,270,17):
            x = math.cos(radius)
            y = math.sin(radius) 
            print((x,y))

# %%
Circle.ordered()

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
class Circle(Shape):
    def __init__(self,radius):
        self.radius = radius
    def circle(self, r):
        self.radius = self.radius + r
        return(self.radius)
    def displayc(self):
        plt.gca().add_patch(plt.Circle((0, 0), radius=self.radius))
        plt.axis('scaled')
        plt.show()  
        print('Radius of object:',C1.radius)
    def __lt__(self,other):
        return self.radius < other.radius
    def __gt__(self,other):
        return self.radius > other.radius

# %%
C1 = Circle(10)
C2 = Circle(50)   
print(C2 > C1) 
print(C2 < C1)
